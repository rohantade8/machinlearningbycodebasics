# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

def gradient_descent(x, y):
    m_curr = b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.01

    for i in range(iterations):
        yp = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y - yp)])
        md = -(2/n) * sum(x * (y - yp))
        bd = -(2/n) * sum(y - yp)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print("Iteration: {}, m: {:.2f}, b: {:.2f}, cost: {:.2f}".format(i, m_curr, b_curr, cost))

x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])

gradient_descent(x, y)
# Out:
# Iteration: 0, m: 0.62, b: 0.18, cost: 89.00
# Iteration: 1, m: 1.09, b: 0.32, cost: 52.25
# Iteration: 2, m: 1.45, b: 0.43, cost: 30.83
# Iteration: 3, m: 1.73, b: 0.51, cost: 18.35
# Iteration: 4, m: 1.94, b: 0.58, cost: 11.07
# Iteration: 5, m: 2.10, b: 0.63, cost: 6.83
# Iteration: 6, m: 2.22, b: 0.67, cost: 4.35
# Iteration: 7, m: 2.31, b: 0.70, cost: 2.91
# Iteration: 8, m: 2.38, b: 0.73, cost: 2.06
# Iteration: 9, m: 2.43, b: 0.75, cost: 1.57
# Iteration: 10, m: 2.47, b: 0.77, cost: 1.28
# Iteration: 11, m: 2.50, b: 0.79, cost: 1.10
# Iteration: 12, m: 2.52, b: 0.80, cost: 1.00
# Iteration: 13, m: 2.54, b: 0.82, cost: 0.94
# Iteration: 14, m: 2.55, b: 0.83, cost: 0.90
# Iteration: 15, m: 2.56, b: 0.84, cost: 0.88
# Iteration: 16, m: 2.57, b: 0.85, cost: 0.86
# Iteration: 17, m: 2.57, b: 0.86, cost: 0.85
# Iteration: 18, m: 2.57, b: 0.87, cost: 0.84
# Iteration: 19, m: 2.58, b: 0.87, cost: 0.83
# Iteration: 20, m: 2.58, b: 0.88, cost: 0.82
# Iteration: 21, m: 2.58, b: 0.89, cost: 0.82
# Iteration: 22, m: 2.58, b: 0.90, cost: 0.81
# Iteration: 23, m: 2.58, b: 0.90, cost: 0.80
# Iteration: 24, m: 2.58, b: 0.91, cost: 0.80
# Iteration: 25, m: 2.57, b: 0.92, cost: 0.79
# Iteration: 26, m: 2.57, b: 0.93, cost: 0.79
# Iteration: 27, m: 2.57, b: 0.93, cost: 0.78
# Iteration: 28, m: 2.57, b: 0.94, cost: 0.78
# Iteration: 29, m: 2.57, b: 0.95, cost: 0.77
# Iteration: 30, m: 2.57, b: 0.95, cost: 0.77
# Iteration: 31, m: 2.56, b: 0.96, cost: 0.76
# Iteration: 32, m: 2.56, b: 0.97, cost: 0.76
# Iteration: 33, m: 2.56, b: 0.98, cost: 0.75
# Iteration: 34, m: 2.56, b: 0.98, cost: 0.75
# Iteration: 35, m: 2.56, b: 0.99, cost: 0.74
# Iteration: 36, m: 2.56, b: 1.00, cost: 0.74
# Iteration: 37, m: 2.55, b: 1.00, cost: 0.73
# Iteration: 38, m: 2.55, b: 1.01, cost: 0.73
# Iteration: 39, m: 2.55, b: 1.02, cost: 0.72
# Iteration: 40, m: 2.55, b: 1.02, cost: 0.72
m: 2.02, b: 2.91, cost: 0.00
# Iteration: 962, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 963, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 964, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 965, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 966, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 967, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 968, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 969, m: 2.02, b: 2.91, cost: 0.00
# Iteration: 970, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 971, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 972, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 973, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 974, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 975, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 976, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 977, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 978, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 979, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 980, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 981, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 982, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 983, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 984, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 985, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 986, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 987, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 988, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 989, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 990, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 991, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 992, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 993, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 994, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 995, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 996, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 997, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 998, m: 2.02, b: 2.92, cost: 0.00
# Iteration: 999, m: 2.02, b: 2.92, cost: 0.00

# %%
# %matplotlib inline
def gradient_descent(x, y):
    m_curr = b_curr = 0
    iterations = 1000
    rate = 0.01  
    n = len(x)
    plt.scatter(x,y,color='red',marker='+',linewidth='5')
    for i in range(10000):
        y_predicted = m_curr * x + b_curr
        # print (m_curr,b_curr,i)
        plt.plot(x,y_predicted,color='green')
        md = -(2/n) * sum(x * (y - y_predicted))
        yd = -(2/n) * sum(y-y_predicted)
        m_curr = m_curr - rate * md
        b_curr = b_curr - rate * yd

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])

# %%
gradient_descent(x, y)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000002BCFFC37920> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File A:\software\Lib\site-packages\matplotlib\pyplot.py:119, in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#
# File A:\software\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File A:\software\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File A:\software\Lib\site-packages\matplotlib\backends\backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\figure.py:3082, in Figure.draw(self, renderer)
#    3079         # ValueError can occur when resizing a window.
#    3081 self.patch.draw(renderer)
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.suppressComposite)
#    3085 for sfig in self.subfigs:
#    3086     sfig.draw(renderer)
#
# File A:\software\Lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\axes\_base.py:3100, in _AxesBase.draw(self, renderer)
#    3097         a.draw(renderer)
#    3098     renderer.stop_rasterizing()
# -> 3100 mimage._draw_list_compositing_images(
#    3101     renderer, self, artists, self.figure.suppressComposite)
#    3103 renderer.close_group('axes')
#    3104 self.stale = False
#
# File A:\software\Lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\collections.py:976, in _CollectionWithSizes.draw(self, renderer)
#     973 @artist.allow_rasterization
#     974 def draw(self, renderer):
#     975     self.set_sizes(self._sizes, self.figure.dpi)
# --> 976     super().draw(renderer)
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\collections.py:406, in Collection.draw(self, renderer)
#     404     gc.set_antialiased(self._antialiaseds[0])
#     405     gc.set_url(self._urls[0])
# --> 406     renderer.draw_markers(
#     407         gc, paths[0], combined_transform.frozen(),
#     408         mpath.Path(offsets), offset_trf, tuple(facecolors[0]))
#     409 else:
#     410     renderer.draw_path_collection(
#     411         gc, transform.frozen(), paths,
#     412         self.get_transforms(), offsets, offset_trf,
#    (...)
#     415         self._antialiaseds, self._urls,
#     416         "screen")  # offset_position, kept for backcompat.
#
# TypeError: must be real number, not str
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File A:\software\Lib\site-packages\IPython\core\formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File A:\software\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File A:\software\Lib\site-packages\matplotlib\backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File A:\software\Lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File A:\software\Lib\site-packages\matplotlib\_api\deprecation.py:410, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     400     deprecation_addendum = (
#     401         f"If any parameter follows {name!r}, they should be passed as "
#     402         f"keyword, not positionally.")
#     403     warn_deprecated(
#     404         since,
#     405         name=repr(name),
#    (...)
#     408                  else deprecation_addendum,
#     409         **kwargs)
# --> 410 return func(*inner_args, **inner_kwargs)
#
# File A:\software\Lib\site-packages\matplotlib\backends\backend_agg.py:517, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     468 @_api.delete_parameter("3.5", "args")
#     469 def print_png(self, filename_or_obj, *args,
#     470               metadata=None, pil_kwargs=None):
#     471     """
#     472     Write the figure to a PNG file.
#     473
#    (...)
#     515         *metadata*, including the default 'Software' key.
#     516     """
# --> 517     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File A:\software\Lib\site-packages\matplotlib\backends\backend_agg.py:463, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     458 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     459     """
#     460     Draw the canvas, then save it using `.image.imsave` (to which
#     461     *pil_kwargs* and *metadata* are forwarded).
#     462     """
# --> 463     FigureCanvasAgg.draw(self)
#     464     mpl.image.imsave(
#     465         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     466         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File A:\software\Lib\site-packages\matplotlib\backends\backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\figure.py:3082, in Figure.draw(self, renderer)
#    3079         # ValueError can occur when resizing a window.
#    3081 self.patch.draw(renderer)
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.suppressComposite)
#    3085 for sfig in self.subfigs:
#    3086     sfig.draw(renderer)
#
# File A:\software\Lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\axes\_base.py:3100, in _AxesBase.draw(self, renderer)
#    3097         a.draw(renderer)
#    3098     renderer.stop_rasterizing()
# -> 3100 mimage._draw_list_compositing_images(
#    3101     renderer, self, artists, self.figure.suppressComposite)
#    3103 renderer.close_group('axes')
#    3104 self.stale = False
#
# File A:\software\Lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\collections.py:976, in _CollectionWithSizes.draw(self, renderer)
#     973 @artist.allow_rasterization
#     974 def draw(self, renderer):
#     975     self.set_sizes(self._sizes, self.figure.dpi)
# --> 976     super().draw(renderer)
#
# File A:\software\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File A:\software\Lib\site-packages\matplotlib\collections.py:406, in Collection.draw(self, renderer)
#     404     gc.set_antialiased(self._antialiaseds[0])
#     405     gc.set_url(self._urls[0])
# --> 406     renderer.draw_markers(
#     407         gc, paths[0], combined_transform.frozen(),
#     408         mpath.Path(offsets), offset_trf, tuple(facecolors[0]))
#     409 else:
#     410     renderer.draw_path_collection(
#     411         gc, transform.frozen(), paths,
#     412         self.get_transforms(), offsets, offset_trf,
#    (...)
#     415         self._antialiaseds, self._urls,
#     416         "screen")  # offset_position, kept for backcompat.
#
# TypeError: must be real number, not str
